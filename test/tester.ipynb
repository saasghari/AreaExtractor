# %%
##### install package instruction

## in local system
# >pip install osmnx
# >pip install F:\Projects\Trajectory\implement\AreaExtractor\AreaExtractor

## in Google Colab
# !pip install osmnx
# !pip install git+https://github.com/saasghari/AreaExtractor.git

# %%
from  AreaExtractor import AE
AE.TestPackage()
# Out:
# AreasExtractor v-1.0.0
